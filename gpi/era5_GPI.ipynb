# %%
'''
# MPI and Genesis Potential for monthly era5 data

- NCSU Large Scale and Tropical Dynamics
- A. Aiyyer
- parts of code adapted from  Wenchang Yang's TCI package


---------------------------------------------------------------------------
Uses:
     - metpy for units aware calculations
     - fortran wrapper for Emanuel's pcmin3 subroutine to calculate TC PI
       PI refers to potential intensity (min sea level pressure and max V)
       see: pcmin_2013.f90 

---------------------------------------------------------------------------
---------------------------------------------------------------------------
Updates:
Oct 20, 2021:  First version
Sep 11, 2022:  Removed code relating to graphics
Dac 12, 2023:  Minor edits to clean up code 
---------------------------------------------------------------------------
---------------------------------------------------------------------------

Notes:

Feb 12, 2023: f2py compilation of pcmin_2013.f90 caused errors. Solved 
temporarily by creating a conda env with numpy=1.21.6, python=3.7.12


Checked result against https://github.com/dgilford/tcpyPI
Practiacally identical estimates of GPI calculation based on PI 
dervied from tcpyPI and the pcmin module

---------------------------------------------------------------------------
'''



import numpy as np
import xarray as xr
import pandas as pd
from datetime import date
from numpy import absolute, exp, log

# Any import of metpy will activate the accessors
from metpy.units import units

#from metpy.calc import dewpoint_from_relative_humidity
from metpy.calc import mixing_ratio_from_specific_humidity, relative_humidity_from_dewpoint

from metpy.calc import absolute_vorticity

# usethe fortran subroutine via the pcmin wrapper
from pcmin import pcmin3

# %%
# What GPI?
# Emanuel and Nolan (2004)
EN2004 = True

# Emanuel 2010
E2010  = False

# %%
# physical parameters
Lv = 2.555e6*units.joules/units.kg # J/kg
g = 9.81*units.meters/(units.second*units.second) #m/s**-2
c_p = 1005.7*units.joules/(units.kelvin*units.kg) # J/kg K   
Rd = 287*units.joules/(units.kelvin*units.kg) # J/kg K
Rv = 461 *units.joules/(units.kelvin*units.kg) # J/kg K   
epsilon = Rd/Rv
T0 = 273.15*units.K

# %%
def potential_intensity(sst, slp, plevels, temperature, mixingratio):
    '''xarray-wrapper of the FORTRAN module pcmin3_kflag.

    '''    
    
    nz = temperature.shape[0]
    ny = temperature.shape[1]
    nx = temperature.shape[2]
    pmin, vmax, iflag = pcmin3(sst, slp, plevels, temperature, mixingratio, ny, nx, nz)
                
    return (pmin,vmax,iflag)


def saturated_vapor_pressure(T):
    '''calculated saturated water vapor pressure (in Pa) given temperature T (in Kelvin)'''    
    svp = (610.94*units.Pa)*exp(17.625*(T-T0)/(T-T0+243.04*units.kelvin))
    return svp

def mixing_ratio(p, e):
    '''calculate mixing ration given air pressure (p) and water vapor pressure (e)'''
    return epsilon*e/(p-e)


def moistEntropy(T, p, RH=None, q=None):
    '''calculate moist entropy given air temperature (T), pressure (p) and relative humidity (RH, 0-1) or specific humidity (q).
    The equation is: s = c_p*log(T) - Rd*log(p_d) + Lv*r_v/T - Rv*r_v*log(RH)'''
    if RH is None:
        assert q is not None, 'at least one of the two variables must be specified: relative humidity/specific humidity'
        r_v = mixing_ratio_by_q(q)
        e = vapor_pressure_by_mixing_ratio(p, r_v)
        RH = e/saturated_vapor_pressure(T)
    else: # RH is from input directly
        e = saturated_vapor_pressure(T) * RH
        r_v = mixing_ratio(p, e) 
        
    s = c_p*log(T/(1*units.kelvin)) - Rd*log((p-e)/(1*units.Pa) ) + Lv*r_v/T - Rv*r_v*log(RH)    
    s.attrs['long_name'] = 'moist entropy'
    #s.attrs['units'] = 'J/K/kg'
    return s


def entropyDeficit(sst, slp, Tb, RHb, p_m, Tm, RHm):
    '''calculate entropy deficity defined in Tang and Emanuel, 2012.
    sst: sea surface temperature (in Kelvin);
    slp: sea level pressure (in Pa);
    Tb: boundary layer air temperature;
    RHb: boundary layer relative humidity (0-1);
    p_m: middle troposphere pressure level (usually 6e4 Pa);
    Tm: middle troposphere air temperature;
    RHm: middle troposphere relative humidity (0-1).'''
 
    s_sst_star = moistEntropy(T=sst, p=slp, RH=1)
    s_b        = moistEntropy(T=Tb, p=slp, RH=RHb)
    s_m_star   = moistEntropy(T=Tm, p=p_m, RH=1)
    s_m        = moistEntropy(T=Tm, p=p_m, RH=RHm)
    
    # pipe/lambda messes with units interesting....
    chi = (s_m_star - s_m)/(s_sst_star - s_b)  #.pipe(lambda x: x.where(x>0)) # exclude values <= 0 
    
    #print(s_sst_star)
    chi.attrs['long_name'] = 'entropy deficit'
    return chi

# %%
# first set the years and months for the processing
year_start = 1980
year_end   = 2022

# %%
# era5
era5_sfc_dir = '/glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/'
era5_pl_dir  = '/glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/'


# subset along latitude
latS = 0.
latN = 30.

# %%
midLevel   =  600*units.hPa
lowLevel   =  850*units.hPa
upperLevel =  200*units.hPa

print('midLevel chosen for calculation of PI and Entropy deficit = ', midLevel)
print('lowLevel chosen for calculation of abs vort and shear = ', lowLevel)
print('upperLevel chosen for calculation of shear = ', upperLevel)
print(' ')
print(' ')


# loop over dates and read the required variables and calculate PI and GP
for year in range(year_start,year_end+1):

    Y = str(year)
    #print(d.year, d.month)
    
    # sst (2D field)
    varId  = '034'
    varNam = 'sstk'
    fname =   Y + '/e5.moda.an.sfc.128_'+varId+'_'+varNam+'.ll025sc.'+Y+'010100_'+Y+'120100.nc'
    infile = era5_sfc_dir + fname
    dsst  = xr.open_dataset(infile)   
    sst = dsst.SSTK.sel(latitude=slice(30,-4), longitude=slice(180,360)).metpy.quantify()
    print("Read SST: ", sst.min().values,  sst.max().values )
    dsst.close()

    #
    # Sea Level Pressure (2D field)
    varId  = '151'
    varNam = 'msl'
    fname =   Y + '/e5.moda.an.sfc.128_'+varId+'_'+varNam+'.ll025sc.'+Y+'010100_'+Y+'120100.nc'
    infile = era5_sfc_dir + fname    
    print(infile)
    dslp  = xr.open_dataset(infile)   
    slp = dslp.MSL.sel(latitude=slice(30,-4), longitude=slice(180,360)).metpy.quantify()
    print("Read MSLP: ", slp.min().values,  slp.max().values )
    dslp.close()


    # ERA interim has Specific Humidity. We need mixing ratio
    # so, first read specific Humidity
    # Specific Humidity q (3D field) 
    varId  = '133'
    varNam = 'q'
    fname =   Y + '/e5.moda.an.pl.128_'+varId+'_'+varNam+'.ll025sc.'+Y+'010100_'+Y+'120100.nc'
    infile = era5_pl_dir + fname    
    print(infile)
    ds  = xr.open_dataset(infile)   
    q = ds.Q.sel(latitude=slice(30,-4), longitude=slice(180,360)).metpy.quantify()
    ds.close()

    #era5 vertical leves are arranged from top to bottom
    q = q.reindex(level=q.level[::-1])

    print("Read Q: ", q.max().values,  q.min().values )
    # now use metpy function to calculate mixing ratio from specific humidity
    mixingRatio = mixing_ratio_from_specific_humidity(q) #kg/kg
    print ('mixing ratio min/max=', mixingRatio.min().values, mixingRatio.max().values)
    # output mixingRatio should be in kg/kg, i.e. dimensionless
    ds.close()



    #
    # temperature (3D field)
    
    varId  = '130'
    varNam = 't'
    fname =   Y + '/e5.moda.an.pl.128_'+varId+'_'+varNam+'.ll025sc.'+Y+'010100_'+Y+'120100.nc'
    infile = era5_pl_dir + fname    
    print(infile)
    ds  = xr.open_dataset(infile)   
    temperature = ds.T.sel(latitude=slice(30,-4), longitude=slice(180,360)).metpy.quantify()
    temperature = temperature.reindex(level=temperature.level[::-1])
    plevels = temperature.level.metpy.convert_units('hPa')
    ds.close()
    print ('T min/max=', temperature.min().values, temperature.max().values)
    #------------------------------------------------------------------------------
    
    # mid level rel humidity
    
    varId  = '157'
    varNam = 'r'
    fname =   Y + '/e5.moda.an.pl.128_'+varId+'_'+varNam+'.ll025sc.'+Y+'010100_'+Y+'120100.nc'
    infile = era5_pl_dir + fname    
    print(infile)
    ds  = xr.open_dataset(infile)   
    relHum = ds.R.sel(latitude=slice(30,-4), longitude=slice(180,360), level=midLevel).metpy.quantify()
    #print ('relHum min/max at ', midLevel, ' hPa=', relHum.min().values, relHum.max().values)
    # convert to dimensionless 
    relHum = relHum/([100.]*units.percent)
    print ('relHum min/max at midLevel hPa=', relHum.min().values, relHum.max().values)


    varId  = '131'
    varNam = 'u'
    fname =   Y + '/e5.moda.an.pl.128_'+varId+'_'+varNam+'.ll025uv.'+Y+'010100_'+Y+'120100.nc'
    infile = era5_pl_dir + fname    
    print(infile)
    ds  = xr.open_dataset(infile)   
    u = ds.U.sel(latitude=slice(30,-4), longitude=slice(180,360), level=lowLevel).metpy.quantify()
    print ('u min/max at low level hPa=', u.min().values, u.max().values)

    u2 = ds.U.sel(latitude=slice(30,-4), longitude=slice(180,360), level=upperLevel).metpy.quantify()
    print ('u2 min/max at upper level hPa=', u2.min().values, u2.max().values)
     

    varId  = '132'
    varNam = 'v'
    fname =   Y + '/e5.moda.an.pl.128_'+varId+'_'+varNam+'.ll025uv.'+Y+'010100_'+Y+'120100.nc'
    infile = era5_pl_dir + fname    
    print(infile)
    ds  = xr.open_dataset(infile)   
    v = ds.V.sel(latitude=slice(30,-4), longitude=slice(180,360), level=lowLevel).metpy.quantify()
    print ('v min/max at low level hPa=', v.min().values, v.max().values)
    v2 = ds.V.sel(latitude=slice(30,-4), longitude=slice(180,360), level=upperLevel).metpy.quantify()
    print ('v2 min/max at upper hPa=', v2.min().values, v2.max().values)
               
        
    # Absolute vorticity at lowLevel (standard to take 850 hPa)
    absVor = absolute_vorticity(u,v,latitude=u.latitude)
    print("Abs Vor = ", absVor.min().values , absVor.max().values)
    
    Vshear = ( (u2 - u)**2 + (v2 - v)**2 )**0.5
    Vshear.attrs['long_name'] = 'wind shear'
    Vshear.attrs['units'] = 'm/s'    
    
    
    
    if (E2010):
        # 2m Temperature
        varId  = '167'
        varNam = '2t'
        fname =   Y + '/e5.moda.an.sfc.128_'+varId+'_'+varNam+'.ll025sc.'+Y+'010100_'+Y+'120100.nc'
        infile = era5_sfc_dir + fname    
        print(infile)
        ds  = xr.open_dataset(infile)   
        T2m = ds.VAR_2T.sel(latitude=slice(30,-4), longitude=slice(180,360)).metpy.quantify()
        print("Read 2T: ", T2m.min().values,  T2m.max().values )
        ds.close()
 
        # 2m Dew Point
        varId  = '168'
        varNam = '2d'
        fname =   Y + '/e5.moda.an.sfc.128_'+varId+'_'+varNam+'.ll025sc.'+Y+'010100_'+Y+'120100.nc'
        infile = era5_sfc_dir + fname    
        print(infile)
        ds  = xr.open_dataset(infile)   
        DP2m = ds.VAR_2D.sel(latitude=slice(30,-4), longitude=slice(180,360)).metpy.quantify()
        print("Read 2DP: ", DP2m.min().values,  DP2m.max().values )
        ds.close()
        #

        RH2m = relative_humidity_from_dewpoint(T2m, DP2m)   
        print("2m Rel Hum = ", RH2m.min().values , RH2m.max().values)
        # RH2m is dimensionless values 0-1

        # Entropy deficit
        p_m  = midLevel.to(units.pascal)
        chi = entropyDeficit(sst=sst,slp=slp,Tb=T2m,RHb=RH2m,
                p_m=p_m,
                Tm=temperature.sel(level=midLevel),
                RHm=relHum)

        print("Chi = ", chi.min().values , chi.max().values)

 
    vmax = xr.DataArray(name="vmax", dims=["time", "latitude","longitude"], 
                    coords= dict(time=(["time"], sst.time.values), latitude=(["latitude"],sst.latitude.values),
                                 longitude=(["longitude"], sst.longitude.values)),
                    attrs=dict(long_name= 'maximum surface wind speed', units = 'm/s') )

    pmin = xr.DataArray(name="pmin", dims=["time", "latitude","longitude"],
                    coords= dict(time=(["time"],   sst.time.values), latitude=(["latitude"],   sst.latitude.values),
                                 longitude=(["longitude"], sst.longitude.values)),
                    attrs=dict(long_name= 'mininum central pressure', units = 'hPa') )

    

    # Potential Intensity calculation
    # can be sped up from what is done below. Need to look into parallel calculation
    for i in range(0,sst.time.shape[0]-1):
        P  = potential_intensity(sst[i,:,:], slp[i,:,:], plevels, temperature[i,:,:,:], mixingRatio[i,:,:,:])
        print(np.nanmin(P[0]), np.nanmax(P[1]))
        vmax[i,:,:] = P[1]
        pmin[i,:,:] = P[0]
   

 
    
    #----------------------------------------------------------------------------------------------------
    # GPI (Emanuel and Nolan 2004): |10**5\eta|**(3/2) * (H/50)**3 * (Vpot/70)**3 * (1+0.1*Vshear)**(-2)
    GPI = (1e5 * absolute(absVor) )**(3/2) \
            * (relHum/0.5)**3 \
            * (vmax/70)**3 \
            * (1*units('m/s')+0.1*Vshear)**(-2)
    GPI.attrs['long_name'] = 'Genesis Potential Index (Emanuel & Nolan 2004)'
    #----------------------------------------------------------------------------------------------------

    # GPI (Emanuel 2010): |\eta|**3 * chi**(-4/3) * max((Vpot-35),0)**2 * (25+Vshear)**(-4)
    #GPI = (absolute(1e5*absVor)**3) * (chi.where(chi>0)**(-4/3)) * ((vmax - 35).clip(min=0)**2) * ((25*units('m/s') + Vshear)**(-4))
    print("GPI = " , GPI.min().values, GPI.max().values, GPI.mean().values)

    ds_out = xr.Dataset({'GPI': GPI.metpy.dequantify(),
                         'VMAX': vmax.metpy.dequantify(),
                         'PMIN': pmin.metpy.dequantify()})
    ofile =  '/glade/work/aiyyer/data/GPI/EN_mon/GP_' + Y + '_EN.nc'
    ds_out.to_netcdf(ofile, "w")

    print('[saved]:', ofile)
# Out:
# midLevel chosen for calculation of PI and Entropy deficit =  600 hectopascal
# lowLevel chosen for calculation of abs vort and shear =  850 hectopascal
# upperLevel chosen for calculation of shear =  200 hectopascal
#
#
# Read SST:  287.02954 305.24683
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/1980/e5.moda.an.sfc.128_151_msl.ll025sc.1980010100_1980120100.nc
# Read MSLP:  100634.44 102712.94
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1980/e5.moda.an.pl.128_133_q.ll025sc.1980010100_1980120100.nc
# Read Q:  0.019543312 1.3414083e-06
# mixing ratio min/max= 1.3414101e-06 0.019932866
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_1993_EN.nc
# Read SST:  284.8396 305.18677
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/1994/e5.moda.an.sfc.128_151_msl.ll025sc.1994010100_1994120100.nc
# Read MSLP:  100618.94 102737.06
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1994/e5.moda.an.pl.128_133_q.ll025sc.1994010100_1994120100.nc
# Read Q:  0.019983096 1.1295806e-06
# mixing ratio min/max= 1.1295818e-06 0.020390563
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1994/e5.moda.an.pl.128_130_t.ll025sc.1994010100_1994120100.nc
# T min/max= 187.11223 314.286
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1994/e5.moda.an.pl.128_157_r.ll025sc.1994010100_1994120100.nc
# relHum min/max at midLevel hPa= 0.03528959274291992 0.9532990264892578
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1994/e5.moda.an.pl.128_131_u.ll025uv.1994010100_1994120100.nc
# u min/max at low level hPa= -17.51297 7.434758
# u2 min/max at upper level hPa= -20.863113 54.348804
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1994/e5.moda.an.pl.128_132_v.ll025uv.1994010100_1994120100.nc
# v min/max at low level hPa= -10.547903 9.579437
# v2 min/max at upper hPa= -19.032425 16.032852
# Abs Vor =  -0.00019623510701965332 0.00027567819444170114
# 866.25085 93.91931
# 842.8427 97.893845
# 846.05493 96.644485
# 845.7438 95.350975
# 838.85425 94.460686
# 837.1372 97.04206
# 840.5319 96.05718
# 834.8254 97.36777
# 836.3055 95.77431
# 831.759 96.99996
# 830.8717 96.46099
# GPI =  0.0 215.86774646182502 1.2115242559233221
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_1994_EN.nc
# Read SST:  286.6504 305.31494
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/1995/e5.moda.an.sfc.128_151_msl.ll025sc.1995010100_1995120100.nc
# Read MSLP:  100491.19 102730.875
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1995/e5.moda.an.pl.128_133_q.ll025sc.1995010100_1995120100.nc
# Read Q:  0.019831985 1.1583215e-06
# mixing ratio min/max= 1.1583229e-06 0.020233251
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1995/e5.moda.an.pl.128_130_t.ll025sc.1995010100_1995120100.nc
# T min/max= 187.62685 314.61462
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1995/e5.moda.an.pl.128_157_r.ll025sc.1995010100_1995120100.nc
# relHum min/max at midLevel hPa= 0.04613758087158203 0.9549002075195312
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1995/e5.moda.an.pl.128_131_u.ll025uv.1995010100_1995120100.nc
# u min/max at low level hPa= -14.190516 15.705093
# u2 min/max at upper level hPa= -20.560806 71.515884
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1995/e5.moda.an.pl.128_132_v.ll025uv.1995010100_1995120100.nc
# v min/max at low level hPa= -11.235718 8.89566
# v2 min/max at upper hPa= -17.014389 15.404358
# Abs Vor =  -0.0001793397915356425 0.0002460580801825114
# 847.7205 96.982056
# 841.2969 100.88604
# 836.9955 97.800575
# 817.61096 100.4421
# 819.0849 100.558044
# 834.4894 96.55873
# 834.9209 97.38
# 838.1462 96.44082
# 831.6895 99.06367
# 829.9099 100.22629
# 842.46124 93.84661
# GPI =  0.0 190.24142534347223 1.1369195538316152
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_1995_EN.nc
# Read SST:  285.7776 304.9265
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/1996/e5.moda.an.sfc.128_151_msl.ll025sc.1996010100_1996120100.nc
# Read MSLP:  100659.31 102559.94
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1996/e5.moda.an.pl.128_133_q.ll025sc.1996010100_1996120100.nc
# Read Q:  0.01938769 1.4264933e-06
# mixing ratio min/max= 1.4264954e-06 0.019771004
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1998/e5.moda.an.pl.128_132_v.ll025uv.1998010100_1998120100.nc
# v min/max at low level hPa= -12.5797415 9.185776
# v2 min/max at upper hPa= -19.724655 16.386673
# Abs Vor =  -0.000217718165126704 0.0002468897251926951
# 829.1718 98.878265
# 827.70715 98.59009
# 806.0277 103.3825
# 815.9605 99.56301
# 834.33496 95.325005
# 841.1283 94.69096
# 834.30084 97.52049
# 835.1042 98.87531
# 832.0531 99.344635
# 828.1618 99.79444
# 823.73016 99.83566
# GPI =  0.0 167.64685425948048 1.209775287453894
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_1998_EN.nc
# Read SST:  285.81763 304.99707
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/1999/e5.moda.an.sfc.128_151_msl.ll025sc.1999010100_1999120100.nc
# Read MSLP:  100527.875 102771.0
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1999/e5.moda.an.pl.128_133_q.ll025sc.1999010100_1999120100.nc
# Read Q:  0.01982172 1.3324479e-06
# mixing ratio min/max= 1.3324496e-06 0.020222565
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1999/e5.moda.an.pl.128_130_t.ll025sc.1999010100_1999120100.nc
# T min/max= 188.44443 316.21194
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1999/e5.moda.an.pl.128_157_r.ll025sc.1999010100_1999120100.nc
# relHum min/max at midLevel hPa= 0.03440254211425781 0.9737777709960938
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1999/e5.moda.an.pl.128_131_u.ll025uv.1999010100_1999120100.nc
# u min/max at low level hPa= -15.435684 9.771347
# u2 min/max at upper level hPa= -23.343796 56.723297
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/1999/e5.moda.an.pl.128_132_v.ll025uv.1999010100_1999120100.nc
# v min/max at low level hPa= -17.237473 9.162161
# v2 min/max at upper hPa= -18.410873 23.689285
# Abs Vor =  -0.00022687703669521368 0.00024702962065751975
# 865.1867 93.250565
# 865.81934 91.57277
# 837.37537 98.13308
# 839.9094 95.949745
# 827.23486 98.258965
# 831.5731 97.66139
# 841.27 96.0064
# 834.2668 97.87575
# 841.3051 96.537094
# 840.75366 99.950294
# 836.8706 97.59103
# GPI =  0.0 180.97523531008954 1.2081763703515995
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_1999_EN.nc
# Read SST:  286.69263 304.94653
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2000/e5.moda.an.sfc.128_151_msl.ll025sc.2000010100_2000120100.nc
# Read MSLP:  100521.125 102664.25
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2000/e5.moda.an.pl.128_133_q.ll025sc.2000010100_2000120100.nc
# Read Q:  0.019445898 1.2174887e-06
# mixing ratio min/max= 1.2174902e-06 0.01983154
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2000/e5.moda.an.pl.128_130_t.ll025sc.2000010100_2000120100.nc
# T min/max= 187.83385 315.33163
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2000/e5.moda.an.pl.128_157_r.ll025sc.2000010100_2000120100.nc
# relHum min/max at midLevel hPa= 0.0355410385131836 0.9857816314697265
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2000/e5.moda.an.pl.128_131_u.ll025uv.2000010100_2000120100.nc
# u min/max at low level hPa= -16.867996 14.259949
# u2 min/max at upper level hPa= -17.959946 58.119507
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2000/e5.moda.an.pl.128_132_v.ll025uv.2000010100_2000120100.nc
# v min/max at low level hPa= -14.40217 9.683728
# v2 min/max at upper hPa= -20.208542 17.198593
# Abs Vor =  -0.00023055841346819874 0.00025778736160567324
# 870.3134 91.15758
# 868.207 93.64309
# 856.25995 94.80717
# 838.40045 96.5785
# 836.2189 95.29561
# 838.5635 95.89501
# 836.54584 97.234795
# 833.0578 97.80811
# 836.4858 96.756744
# 832.933 96.76241
# 820.9205 100.014305
# GPI =  0.0 193.5902137693067 1.2274055347155062
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2003/e5.moda.an.pl.128_133_q.ll025sc.2003010100_2003120100.nc
# Read Q:  0.019324826 1.120844e-06
# mixing ratio min/max= 1.1208452e-06 0.019705635
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2003/e5.moda.an.pl.128_130_t.ll025sc.2003010100_2003120100.nc
# T min/max= 186.96571 315.73718
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2003/e5.moda.an.pl.128_157_r.ll025sc.2003010100_2003120100.nc
# relHum min/max at midLevel hPa= 0.03510136604309082 0.9555140686035156
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2003/e5.moda.an.pl.128_131_u.ll025uv.2003010100_2003120100.nc
# u min/max at low level hPa= -16.34378 16.756805
# u2 min/max at upper level hPa= -17.246384 70.37889
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2003/e5.moda.an.pl.128_132_v.ll025uv.2003010100_2003120100.nc
# v min/max at low level hPa= -15.55263 9.306992
# v2 min/max at upper hPa= -17.642868 14.897171
# Abs Vor =  -0.00021439668854619174 0.00024353582853424893
# 849.4512 96.61388
# 826.8425 100.76403
# 807.3389 106.21035
# 821.1496 100.13741
# 820.00006 99.718185
# 842.2667 94.284256
# 835.9997 96.964775
# 834.76086 97.15869
# 832.2415 97.27258
# 832.4036 99.22978
# 829.26 97.78232
# GPI =  0.0 203.22098838196968 1.3508364044841779
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2003_EN.nc
# Read SST:  285.2256 305.81494
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2004/e5.moda.an.sfc.128_151_msl.ll025sc.2004010100_2004120100.nc
# Read MSLP:  100644.25 102551.625
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2004/e5.moda.an.pl.128_133_q.ll025sc.2004010100_2004120100.nc
# Read Q:  0.019397527 1.2310202e-06
# mixing ratio min/max= 1.2310218e-06 0.019781234
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2004/e5.moda.an.pl.128_130_t.ll025sc.2004010100_2004120100.nc
# T min/max= 187.91817 313.84607
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2004/e5.moda.an.pl.128_157_r.ll025sc.2004010100_2004120100.nc
# relHum min/max at midLevel hPa= 0.0375136661529541 0.9630928039550781
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2004/e5.moda.an.pl.128_131_u.ll025uv.2004010100_2004120100.nc
# u min/max at low level hPa= -17.44632 14.116424
# u2 min/max at upper level hPa= -18.07399 66.84869
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2004/e5.moda.an.pl.128_132_v.ll025uv.2004010100_2004120100.nc
# v min/max at low level hPa= -12.958594 10.181717
# v2 min/max at upper hPa= -17.057098 19.005142
# Abs Vor =  -0.00022411248190266106 0.0002486142837675374
# 831.79504 96.84294
# 844.47705 97.88427
# 830.6309 99.34302
# 845.38556 93.19286
# 840.88385 93.68608
# 833.7279 96.87594
# 838.6155 96.06304
# 825.5701 99.5993
# 832.6427 97.19601
# 832.259 98.678345
# 826.8975 99.106606
# GPI =  0.0 213.4557657750667 1.3319263512443447
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2004_EN.nc
# Read SST:  286.64697 305.72754
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2005/e5.moda.an.sfc.128_151_msl.ll025sc.2005010100_2005120100.nc
# Read MSLP:  100603.625 102510.0
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2005/e5.moda.an.pl.128_133_q.ll025sc.2005010100_2005120100.nc
# Read Q:  0.019950699 1.2286782e-06
# mixing ratio min/max= 1.2286798e-06 0.020356832
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2005/e5.moda.an.pl.128_130_t.ll025sc.2005010100_2005120100.nc
# T min/max= 187.67366 315.46692
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2005/e5.moda.an.pl.128_157_r.ll025sc.2005010100_2005120100.nc
# relHum min/max at midLevel hPa= 0.04750063896179199 0.938697280883789
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2005/e5.moda.an.pl.128_131_u.ll025uv.2005010100_2005120100.nc
# u min/max at low level hPa= -15.931887 14.736572
# u2 min/max at upper level hPa= -16.779846 64.43763
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2005/e5.moda.an.pl.128_132_v.ll025uv.2005010100_2005120100.nc
# v min/max at low level hPa= -12.807473 10.044418
# v2 min/max at upper hPa= -20.934769 21.150925
# Abs Vor =  -0.00020429577396844953 0.0002616862713761167
# 840.41376 94.45132
# 864.02814 92.25329
# 809.8003 103.80938
# 814.2304 100.90413
# 832.65515 95.83236
# 816.60895 100.2633
# 823.62463 99.87903
# 825.81335 99.14251
# 811.77606 102.779106
# 827.21185 100.893166
# 811.2811 102.44301
# GPI =  0.0 170.65147866309647 1.3301498158384943
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2005_EN.nc
# Read SST:  286.58105 305.54028
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2006/e5.moda.an.sfc.128_151_msl.ll025sc.2006010100_2006120100.nc
# Read MSLP:  100604.44 102622.31
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2006/e5.moda.an.pl.128_133_q.ll025sc.2006010100_2006120100.nc
# Read Q:  0.019748308 1.1704979e-06
# mixing ratio min/max= 1.1704992e-06 0.020146161
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2006/e5.moda.an.pl.128_130_t.ll025sc.2006010100_2006120100.nc
# T min/max= 187.2957 314.69055
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2006/e5.moda.an.pl.128_157_r.ll025sc.2006010100_2006120100.nc
# relHum min/max at midLevel hPa= 0.03725780487060547 0.9388984680175781
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2006/e5.moda.an.pl.128_131_u.ll025uv.2006010100_2006120100.nc
# u min/max at low level hPa= -16.09877 10.791534
# u2 min/max at upper level hPa= -18.41069 54.586777
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2006/e5.moda.an.pl.128_132_v.ll025uv.2006010100_2006120100.nc
# v min/max at low level hPa= -12.005818 9.739304
# v2 min/max at upper hPa= -17.972397 16.612274
# Abs Vor =  -0.00021084843207225064 0.000247822425772455
# 861.9038 92.726364
# 851.11926 96.97538
# 853.51514 95.41094
# 842.49243 94.17868
# 828.53577 97.34328
# 823.29987 99.62952
# 833.1279 97.435394
# 829.8686 98.28668
# 829.5358 98.31437
# 825.08185 98.76453
# 837.35016 97.68675
# GPI =  0.0 157.75322236562516 1.3837979076311768
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2006_EN.nc
# Read SST:  285.05005 305.1587
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2007/e5.moda.an.sfc.128_151_msl.ll025sc.2007010100_2007120100.nc
# Read MSLP:  100613.25 102701.06
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2007/e5.moda.an.pl.128_133_q.ll025sc.2007010100_2007120100.nc
# Read Q:  0.019539528 1.3555791e-06
# mixing ratio min/max= 1.3555809e-06 0.01992893
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2007/e5.moda.an.pl.128_130_t.ll025sc.2007010100_2007120100.nc
# T min/max= 188.09734 314.1198
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2007/e5.moda.an.pl.128_157_r.ll025sc.2007010100_2007120100.nc
# relHum min/max at midLevel hPa= 0.043328800201416016 0.9594865417480469
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2007/e5.moda.an.pl.128_131_u.ll025uv.2007010100_2007120100.nc
# u min/max at low level hPa= -17.34404 11.1679535
# u2 min/max at upper level hPa= -23.119781 60.138504
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2007/e5.moda.an.pl.128_132_v.ll025uv.2007010100_2007120100.nc
# v min/max at low level hPa= -15.326524 9.1604
# v2 min/max at upper hPa= -17.372467 17.44878
# Abs Vor =  -0.00021929859902782925 0.00026114406227071695
# 847.4883 94.95959
# 849.4516 99.55591
# 828.74786 99.648155
# 839.3918 94.606514
# 832.782 96.2178
# 834.20056 97.15845
# 836.1591 97.56588
# 843.0983 94.83468
# 837.312 97.09518
# 828.5685 98.33902
# 829.23895 98.04026
# GPI =  0.0 202.82255304437925 1.1685639380162387
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2007_EN.nc
# Read SST:  286.49048 305.22656
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2008/e5.moda.an.sfc.128_151_msl.ll025sc.2008010100_2008120100.nc
# Read MSLP:  100597.75 102771.56
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2008/e5.moda.an.pl.128_133_q.ll025sc.2008010100_2008120100.nc
# Read Q:  0.019717868 1.2578694e-06
# mixing ratio min/max= 1.257871e-06 0.020114483
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2008/e5.moda.an.pl.128_130_t.ll025sc.2008010100_2008120100.nc
# T min/max= 187.74113 315.14423
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2008/e5.moda.an.pl.128_157_r.ll025sc.2008010100_2008120100.nc
# relHum min/max at midLevel hPa= 0.041597299575805664 0.98012451171875
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2008/e5.moda.an.pl.128_131_u.ll025uv.2008010100_2008120100.nc
# u min/max at low level hPa= -16.729996 10.795166
# u2 min/max at upper level hPa= -22.17714 51.24565
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2008/e5.moda.an.pl.128_132_v.ll025uv.2008010100_2008120100.nc
# v min/max at low level hPa= -15.856578 11.076767
# v2 min/max at upper hPa= -21.639587 18.1651
# Abs Vor =  -0.00021682459294811594 0.00025294808650260333
# 866.1669 94.63155
# 855.5235 97.20794
# 833.0971 100.80259
# 829.90594 97.71277
# 838.6673 95.65711
# 833.99194 97.637
# 842.0787 95.13198
# 839.86426 95.77278
# 828.1339 98.628914
# 836.95294 97.41885
# 828.3605 97.75359
# GPI =  0.0 173.18228007831928 1.1583501800581755
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2008_EN.nc
# Read SST:  287.1057 305.7959
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2009/e5.moda.an.sfc.128_151_msl.ll025sc.2009010100_2009120100.nc
# Read MSLP:  100665.25 102752.25
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2009/e5.moda.an.pl.128_133_q.ll025sc.2009010100_2009120100.nc
# Read Q:  0.020128777 1.4044626e-06
# mixing ratio min/max= 1.4044647e-06 0.020542268
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2009/e5.moda.an.pl.128_130_t.ll025sc.2009010100_2009120100.nc
# T min/max= 188.4007 314.85608
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2009/e5.moda.an.pl.128_157_r.ll025sc.2009010100_2009120100.nc
# relHum min/max at midLevel hPa= 0.038446512222290036 0.9444321441650391
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2009/e5.moda.an.pl.128_131_u.ll025uv.2009010100_2009120100.nc
# u min/max at low level hPa= -17.72255 12.02605
# u2 min/max at upper level hPa= -18.820984 55.710896
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2009/e5.moda.an.pl.128_132_v.ll025uv.2009010100_2009120100.nc
# v min/max at low level hPa= -13.59612 9.1783905
# v2 min/max at upper hPa= -17.708588 17.19226
# Abs Vor =  -0.000205029854594136 0.0002627916034864407
# 866.0163 91.75679
# 869.66437 91.81641
# 859.43506 94.46346
# 828.785 99.854256
# 835.515 95.96218
# 830.02075 97.29486
# 837.10455 96.72323
# 838.94995 95.59016
# 824.4888 99.18135
# 810.41125 103.03568
# 804.978 103.826904
# GPI =  0.0 193.39254436349984 1.2515692915348005
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2009_EN.nc
# Read SST:  286.54102 305.5974
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2010/e5.moda.an.sfc.128_151_msl.ll025sc.2010010100_2010120100.nc
# Read MSLP:  100613.5 102740.69
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2010/e5.moda.an.pl.128_133_q.ll025sc.2010010100_2010120100.nc
# Read Q:  0.020571163 1.29808e-06
# mixing ratio min/max= 1.2980817e-06 0.021003224
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2010/e5.moda.an.pl.128_130_t.ll025sc.2010010100_2010120100.nc
# T min/max= 188.22076 314.4524
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2010/e5.moda.an.pl.128_157_r.ll025sc.2010010100_2010120100.nc
# relHum min/max at midLevel hPa= 0.03890616416931152 0.9628287506103516
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2010/e5.moda.an.pl.128_131_u.ll025uv.2010010100_2010120100.nc
# u min/max at low level hPa= -17.869156 16.5215
# u2 min/max at upper level hPa= -20.26088 64.111
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2010/e5.moda.an.pl.128_132_v.ll025uv.2010010100_2010120100.nc
# v min/max at low level hPa= -13.050734 9.418556
# v2 min/max at upper hPa= -17.45488 14.63707
# Abs Vor =  -0.00018026601413154698 0.00024720635765039983
# 849.774 95.6313
# 828.7239 97.719795
# 820.51746 98.47354
# 823.5626 98.09253
# 834.75977 95.64118
# 844.5159 94.13511
# 840.13385 95.57973
# 832.0448 97.55028
# 833.1715 98.58056
# 821.7051 99.68937
# 834.55273 95.15023
# GPI =  0.0 262.0051428367858 1.1594093193676644
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2010_EN.nc
# Read SST:  286.0205 305.239
# ...
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2012/e5.moda.an.pl.128_132_v.ll025uv.2012010100_2012120100.nc
# v min/max at low level hPa= -15.716821 10.245346
# v2 min/max at upper hPa= -21.956497 20.294922
# Abs Vor =  -0.00021753636361055505 0.0002563295801333028
# 855.3061 95.136375
# 853.7498 97.166466
# 841.6174 96.85291
# 837.7085 95.43505
# 816.8124 100.55248
# 826.61444 99.2832
# 833.713 97.19155
# 839.18915 98.38175
# 821.8726 101.01779
# 813.89594 101.81404
# 807.9855 105.7406
# GPI =  0.0 173.63670890071018 1.171568975379736
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2012_EN.nc
# Read SST:  287.03735 305.2898
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2013/e5.moda.an.sfc.128_151_msl.ll025sc.2013010100_2013120100.nc
# Read MSLP:  100634.375 102776.69
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2013/e5.moda.an.pl.128_133_q.ll025sc.2013010100_2013120100.nc
# Read Q:  0.020164803 1.2894216e-06
# mixing ratio min/max= 1.2894233e-06 0.020579789
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2013/e5.moda.an.pl.128_130_t.ll025sc.2013010100_2013120100.nc
# T min/max= 188.03398 314.8449
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2013/e5.moda.an.pl.128_157_r.ll025sc.2013010100_2013120100.nc
# relHum min/max at midLevel hPa= 0.030463857650756834 0.9468756103515625
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2013/e5.moda.an.pl.128_131_u.ll025uv.2013010100_2013120100.nc
# u min/max at low level hPa= -16.508453 11.593109
# u2 min/max at upper level hPa= -19.136505 58.069473
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2013/e5.moda.an.pl.128_132_v.ll025uv.2013010100_2013120100.nc
# v min/max at low level hPa= -13.392315 9.093613
# v2 min/max at upper hPa= -21.300568 18.016815
# Abs Vor =  -0.00020591378370351908 0.0002555810063231679
# 862.8759 93.817726
# 841.34656 98.57311
# 832.8625 97.021324
# 811.5749 102.5307
# 841.77203 94.64069
# 843.1315 97.421936
# 836.0271 97.0114
# 838.2575 95.94617
# 834.70465 96.33966
# 822.41254 100.67571
# 840.4873 96.930954
# GPI =  0.0 197.99927385520894 1.1689838794019065
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2016/e5.moda.an.pl.128_130_t.ll025sc.2016010100_2016120100.nc
# T min/max= 189.31233 313.9985
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2016/e5.moda.an.pl.128_157_r.ll025sc.2016010100_2016120100.nc
# relHum min/max at midLevel hPa= 0.035062427520751956 0.953699951171875
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2016/e5.moda.an.pl.128_131_u.ll025uv.2016010100_2016120100.nc
# u min/max at low level hPa= -16.242126 15.205213
# u2 min/max at upper level hPa= -20.155304 62.093296
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2016/e5.moda.an.pl.128_132_v.ll025uv.2016010100_2016120100.nc
# v min/max at low level hPa= -13.882254 10.122665
# v2 min/max at upper hPa= -20.235397 17.704056
# Abs Vor =  -0.00020247645875205706 0.0002517051355336336
# 827.5102 100.04863
# 833.12384 98.39115
# 809.4265 104.57532
# 810.8768 102.77891
# 817.75275 100.4071
# 826.71796 99.34167
# 833.6364 97.8847
# 815.4138 101.93345
# 835.58527 97.47736
# 823.7202 99.02491
# 829.8732 99.893486
# GPI =  0.0 195.69663089180528 1.3712069461879828
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2016_EN.nc
# Read SST:  287.61182 305.58325
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2017/e5.moda.an.sfc.128_151_msl.ll025sc.2017010100_2017120100.nc
# Read MSLP:  100690.125 102613.5
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2017/e5.moda.an.pl.128_133_q.ll025sc.2017010100_2017120100.nc
# Read Q:  0.020547 1.5196829e-06
# mixing ratio min/max= 1.5196852e-06 0.020978035
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2017/e5.moda.an.pl.128_130_t.ll025sc.2017010100_2017120100.nc
# T min/max= 188.89763 314.87488
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2017/e5.moda.an.pl.128_157_r.ll025sc.2017010100_2017120100.nc
# relHum min/max at midLevel hPa= 0.04518835067749023 0.9478018951416015
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2017/e5.moda.an.pl.128_131_u.ll025uv.2017010100_2017120100.nc
# u min/max at low level hPa= -15.295639 11.547409
# u2 min/max at upper level hPa= -18.818283 57.3172
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2017/e5.moda.an.pl.128_132_v.ll025uv.2017010100_2017120100.nc
# v min/max at low level hPa= -13.175832 11.254669
# v2 min/max at upper hPa= -29.519974 17.40776
# Abs Vor =  -0.0002233881454235757 0.00024414972312690583
# 863.26105 95.67462
# 842.3264 100.85021
# 844.8377 96.43276
# 815.237 101.19079
# 826.6509 98.10291
# 838.2212 96.0028
# 834.4241 97.56297
# 831.9115 98.00118
# 824.4732 99.117386
# 828.21796 97.52224
# 828.6161 98.561455
# GPI =  0.0 174.7112395778901 1.1516018684967368
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2017_EN.nc
# Read SST:  285.4978 306.21753
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2018/e5.moda.an.sfc.128_151_msl.ll025sc.2018010100_2018120100.nc
# Read MSLP:  100682.94 102846.69
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2018/e5.moda.an.pl.128_133_q.ll025sc.2018010100_2018120100.nc
# Read Q:  0.02035812 1.4696352e-06
# mixing ratio min/max= 1.4696374e-06 0.020781185
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2018/e5.moda.an.pl.128_130_t.ll025sc.2018010100_2018120100.nc
# T min/max= 189.12709 316.39984
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2018/e5.moda.an.pl.128_157_r.ll025sc.2018010100_2018120100.nc
# relHum min/max at midLevel hPa= 0.03827579498291016 0.9662496948242187
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2018/e5.moda.an.pl.128_131_u.ll025uv.2018010100_2018120100.nc
# u min/max at low level hPa= -18.34555 11.005096
# u2 min/max at upper level hPa= -18.698029 54.6707
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2018/e5.moda.an.pl.128_132_v.ll025uv.2018010100_2018120100.nc
# v min/max at low level hPa= -16.224167 10.262365
# v2 min/max at upper hPa= -20.186005 17.92337
# Abs Vor =  -0.00023145633704450415 0.00027407785887109833
# 846.9626 96.24082
# 863.50775 99.01724
# 809.5377 107.37649
# 827.72186 99.32412
# 828.6394 98.20339
# 829.16125 98.471466
# 835.84546 97.25973
# 824.0561 100.880714
# 830.7158 98.52126
# 799.94885 105.71566
# 823.9808 97.73679
# GPI =  0.0 185.27769951026224 1.2672950923328403
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2018_EN.nc
# Read SST:  286.53906 306.43433
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2019/e5.moda.an.sfc.128_151_msl.ll025sc.2019010100_2019120100.nc
# Read MSLP:  100598.125 102575.75
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2019/e5.moda.an.pl.128_133_q.ll025sc.2019010100_2019120100.nc
# Read Q:  0.019997766 1.273891e-06
# mixing ratio min/max= 1.2738926e-06 0.020405838
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2019/e5.moda.an.pl.128_130_t.ll025sc.2019010100_2019120100.nc
# T min/max= 187.0292 315.42487
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2019/e5.moda.an.pl.128_157_r.ll025sc.2019010100_2019120100.nc
# relHum min/max at midLevel hPa= 0.03662785530090332 0.9381169128417969
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2019/e5.moda.an.pl.128_131_u.ll025uv.2019010100_2019120100.nc
# u min/max at low level hPa= -15.296355 10.583528
# u2 min/max at upper level hPa= -19.310883 60.272545
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2019/e5.moda.an.pl.128_132_v.ll025uv.2019010100_2019120100.nc
# v min/max at low level hPa= -11.784527 12.480652
# v2 min/max at upper hPa= -21.43753 19.546188
# Abs Vor =  -0.00023001843569488744 0.0002695642907534896
# 850.73615 99.44128
# 836.2322 102.04127
# 804.3104 106.09198
# 812.1843 103.20376
# 826.398 97.86108
# 839.5439 95.46326
# 830.8267 99.17782
# 816.75977 102.53684
# 815.769 101.751114
# 837.01825 97.81769
# 837.2138 95.743645
# GPI =  0.0 165.75455582050003 1.2861862158638082
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2019_EN.nc
# Read SST:  287.60742 306.4148
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2020/e5.moda.an.sfc.128_151_msl.ll025sc.2020010100_2020120100.nc
# Read MSLP:  100598.375 102703.375
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2020/e5.moda.an.pl.128_133_q.ll025sc.2020010100_2020120100.nc
# Read Q:  0.020030169 1.6209706e-06
# mixing ratio min/max= 1.6209732e-06 0.020439576
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2020/e5.moda.an.pl.128_130_t.ll025sc.2020010100_2020120100.nc
# T min/max= 189.27528 314.81763
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2020/e5.moda.an.pl.128_157_r.ll025sc.2020010100_2020120100.nc
# relHum min/max at midLevel hPa= 0.038006868362426754 0.9445635223388672
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2020/e5.moda.an.pl.128_131_u.ll025uv.2020010100_2020120100.nc
# u min/max at low level hPa= -14.732681 10.09703
# u2 min/max at upper level hPa= -21.319916 52.975895
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2020/e5.moda.an.pl.128_132_v.ll025uv.2020010100_2020120100.nc
# v min/max at low level hPa= -14.765781 8.525238
# v2 min/max at upper hPa= -19.883057 17.453125
# Abs Vor =  -0.0001862155963630863 0.00023297609136809118
# 852.9389 98.15378
# 837.10236 101.9529
# 831.80023 103.7881
# 817.2706 101.80193
# 803.27014 104.71331
# 834.9242 97.0575
# 832.49 97.788
# 833.2523 97.63919
# 827.45294 100.17965
# 817.90094 101.88683
# 842.6061 97.43811
# GPI =  0.0 167.1152575685397 1.2105778189285314
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2020_EN.nc
# Read SST:  286.1194 305.32617
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2021/e5.moda.an.sfc.128_151_msl.ll025sc.2021010100_2021120100.nc
# Read MSLP:  100638.0 102649.56
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2021/e5.moda.an.pl.128_133_q.ll025sc.2021010100_2021120100.nc
# Read Q:  0.01980138 1.499222e-06
# mixing ratio min/max= 1.4992243e-06 0.020201396
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2021/e5.moda.an.pl.128_130_t.ll025sc.2021010100_2021120100.nc
# T min/max= 188.93648 316.1926
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2021/e5.moda.an.pl.128_157_r.ll025sc.2021010100_2021120100.nc
# relHum min/max at midLevel hPa= 0.03892304420471191 0.9610411071777344
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2021/e5.moda.an.pl.128_131_u.ll025uv.2021010100_2021120100.nc
# u min/max at low level hPa= -15.410416 11.461655
# u2 min/max at upper level hPa= -20.794327 52.810806
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2021/e5.moda.an.pl.128_132_v.ll025uv.2021010100_2021120100.nc
# v min/max at low level hPa= -14.2102785 9.208588
# v2 min/max at upper hPa= -24.14032 16.048904
# Abs Vor =  -0.0002148979788461777 0.00023594065063175108
# 859.7741 95.52565
# 835.5269 101.995895
# 840.0848 100.21928
# 832.2526 97.45223
# 840.99524 95.63235
# 848.8231 93.90444
# 839.3714 97.00885
# 832.6101 98.77346
# 832.7538 98.13346
# 831.5309 99.145515
# 840.76337 99.53533
# GPI =  0.0 207.59132034680147 1.1193297501471804
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2021_EN.nc
# Read SST:  285.86646 305.69824
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.sfc/2022/e5.moda.an.sfc.128_151_msl.ll025sc.2022010100_2022120100.nc
# Read MSLP:  100630.69 102631.0
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2022/e5.moda.an.pl.128_133_q.ll025sc.2022010100_2022120100.nc
# Read Q:  0.019639475 1.6711365e-06
# mixing ratio min/max= 1.6711393e-06 0.02003291
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2022/e5.moda.an.pl.128_130_t.ll025sc.2022010100_2022120100.nc
# T min/max= 189.2089 314.4093
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2022/e5.moda.an.pl.128_157_r.ll025sc.2022010100_2022120100.nc
# relHum min/max at midLevel hPa= 0.05068248748779297 0.9509634399414062
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2022/e5.moda.an.pl.128_131_u.ll025uv.2022010100_2022120100.nc
# u min/max at low level hPa= -14.810165 15.160957
# u2 min/max at upper level hPa= -19.510452 66.22273
# /glade/campaign/collections/rda/data/ds633.1/e5.moda.an.pl/2022/e5.moda.an.pl.128_132_v.ll025uv.2022010100_2022120100.nc
# v min/max at low level hPa= -10.458498 10.125316
# v2 min/max at upper hPa= -22.072952 13.455292
# Abs Vor =  -0.00018399941127562254 0.00023901863618648638
# 855.3889 98.04642
# 852.052 99.04595
# 838.60565 99.07531
# 827.69727 99.04633
# 828.769 98.57055
# 833.4273 98.263084
# 836.2057 97.10114
# 833.396 98.43334
# 825.999 101.04565
# 828.8697 99.64656
# 841.7601 95.91745
# GPI =  0.0 295.9614973622238 1.1484189614670242
# [saved]: /glade/work/aiyyer/data/GPI/EN_mon/GP_2022_EN.nc
